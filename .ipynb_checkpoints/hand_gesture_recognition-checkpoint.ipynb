# %%
# Importing necessary packages

import keras

from keras.layers import Dense,GlobalAveragePooling2D
from keras.applications import MobileNet
from keras.preprocessing import image
from keras.applications.mobilenet import preprocess_input
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Model
from keras.optimizers import Adam
from keras.applications.vgg19 import VGG19
from keras.applications.mobilenet import MobileNet
from sklearn.linear_model import Ridge
import os
import pandas as pd
from sklearn.metrics import *
from sklearn import linear_model
from sklearn.model_selection import cross_val_score
from collections import defaultdict as dd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn import linear_model
from slir import SparseLinearRegression

import operator
import re
from collections import Counter

from IPython.display import HTML, display
from IPython.display import Image

import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib import cm
from mpl_toolkits.mplot3d import Axes3D
# %matplotlib  

import pickle

from utils import detector_utils as detector_utils
import cv2
import tensorflow as tf

from keras.models import Sequential
from keras.layers import Dense
from keras import losses
# Out:
# C:\Users\Theodora\Anaconda3\envs\py35\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# Using matplotlib backend: Qt4Agg

# %%
# The 10 possible gesture labels (and other global variables, irrelevant stuff etc etc)

gestures = {
    1:"fist",
    2:"index",
    3:"pinky",
    4:"l",
    5:"two",
    6:"three",
    7:"ronaldinho",
    8:"metal",
    9:"palm",
    10:"jesus"
}

# %%
# Preprocessing the image

# Cropping the hand from the whole image

def detect_hand(path):
    image_np = cv2.imread(path)
    (h, w, d) = image_np.shape
    im_width, im_height = w, h

    try:
        image_np = cv2.cvtColor(image_np, cv2.COLOR_BGR2RGB)
    except:
        print("Error converting to RGB")

    # Actual detection. Variable boxes contains the bounding box cordinates for hands detected,
    # while scores contains the confidence for each of these boxes.
    # Hint: If len(boxes) > 1 , you may assume you have found atleast one hand (within your score threshold)
    boxes, scores = detector_utils.detect_objects(image_np,
                                                    detection_graph, sess)

    
    hand = detector_utils.get_roi(num_hands_detect, 0.2, scores, boxes, im_width, im_height,image_np)

    try:
       return hand
    except:
        print("No hands")
        return None

# %%
"""
# Uncomment this only if desired to crop hands automatically.
# Not advised.
# Directory with original images
picture_dir = ".\\poses_kinect"

# Directory with cropped hands
destination_dir = ".\\automatically_cropped"
os.mkdir(destination_dir)

# max number of hands we want to detect/track
num_hands_detect = 2

#Load the pretrained model
# os.chdir("..")
detection_graph, sess = detector_utils.load_inference_graph()

# For each gesture, we create its subfolder
for g in gestures:
    dir_name = destination_dir + "\\" + gestures[g]
    os.mkdir(dir_name)

# Changing the current directory to the directory of cropped hands
# os.chdir(picture_dir)

number = 0
for (dirpath, dirnames, filenames) in os.walk(picture_dir):
    for filename in filenames:
        path = os.path.join(dirpath, filename)
        gesture = os.path.basename(os.path.dirname(path)) 
        hand = detect_hand(path)
        if hand is not None:
            dest_path = destination_dir + "\\" + gesture + "\\" + str(number) + ".jpg"
            cv2.imwrite(dest_path, cv2.cvtColor(hand, cv2.COLOR_RGB2BGR))
            number += 1
"""      
# Removing background
# Out:
# '\n# Uncomment this only if desired to crop hands automatically.\n# Not advised.\n# Directory with original images\npicture_dir = ".\\poses_kinect"\n\n# Directory with cropped hands\ndestination_dir = ".\\automatically_cropped"\nos.mkdir(destination_dir)\n\n# max number of hands we want to detect/track\nnum_hands_detect = 2\n\n#Load the pretrained model\n# os.chdir("..")\ndetection_graph, sess = detector_utils.load_inference_graph()\n\n# For each gesture, we create its subfolder\nfor g in gestures:\n    dir_name = destination_dir + "\\" + gestures[g]\n    os.mkdir(dir_name)\n\n# Changing the current directory to the directory of cropped hands\n# os.chdir(picture_dir)\n\nnumber = 0\nfor (dirpath, dirnames, filenames) in os.walk(picture_dir):\n    for filename in filenames:\n        path = os.path.join(dirpath, filename)\n        gesture = os.path.basename(os.path.dirname(path)) \n        hand = detect_hand(path)\n        if hand is not None:\n            dest_path = destination_dir + "\\" + gesture + "\\" + str(number) + ".jpg"\n            cv2.imwrite(dest_path, cv2.cvtColor(hand, cv2.COLOR_RGB2BGR))\n            number += 1\n'

# %%
# Visual-features-only : Experiment one, CNN from Scratch

# %%
# Visual-features-only : Experiment two, transfer learning, using VGG19

# os.chdir("..")
# print(os.getcwd())
# Transfer learning with VGG19
base_model=VGG19(weights='imagenet',include_top=False, input_shape = (128, 128, 3)) #imports the VGG19 model and discards the last 1000 neuron layer.

x = base_model.output
x = GlobalAveragePooling2D()(x)

# Adding dense layers so that the model can learn more complex functions and classify for better results.
x = Dense(512,activation='relu')(x)

# Dense layer 2
x = Dense(512,activation='relu')(x) 

# Dense layer 3
x = Dense(512,activation='relu')(x) 
preds = Dense(10,activation='softmax')(x) #final layer with softmax activation

# Load the previously created model
model=Model(inputs=base_model.input,outputs=preds)

# TODO : what does this do ?

for layer in model.layers[:20]:
    layer.trainable=False
for layer in model.layers[20:]:
    layer.trainable=True
    
# Prepare the data for training
batch_size = 32
validation_split = 0.2
epochs = 1 # WILL PUT 100 AFTER TESTING ALL CODE

train_datagen = ImageDataGenerator(preprocessing_function=preprocess_input, validation_split=validation_split)

print(os.getcwd())
train_generator = train_datagen.flow_from_directory(
    '.\\poses',
    target_size=(128,128),
     color_mode='rgb',
     batch_size=batch_size,
     class_mode='categorical',
     subset = 'training') # set as training data


validation_generator = train_datagen.flow_from_directory(
    '.\\poses',
    target_size=(128,128),
     color_mode='rgb',
     batch_size=batch_size,
     class_mode='categorical',
     subset = 'validation') # set as validation data


step_size_train=train_generator.n//train_generator.batch_size
# Out:
# WARNING:tensorflow:From C:\Users\Theodora\Anaconda3\envs\py35\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# D:\FINAL_PROJECT_PI4
# Found 559 images belonging to 10 classes.
# Found 133 images belonging to 10 classes.

# %%
# Compiling and fitting the model and getting results
opt = Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False)
model.compile(optimizer='Adam',loss='categorical_crossentropy',metrics=['accuracy'])
history = model.fit_generator(
    train_generator,
    steps_per_epoch = train_generator.samples // batch_size,
    validation_data = validation_generator, 
    validation_steps = validation_generator.samples // batch_size,
    epochs = epochs)
# Out:
# WARNING:tensorflow:From C:\Users\Theodora\Anaconda3\envs\py35\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/1
# 17/17 [==============================] - 251s 15s/step - loss: 2.1215 - acc: 0.2390 - val_loss: 1.6852 - val_acc: 0.4141

# %%
# Summarize history for accuracy
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# Summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
# General function to create a dataframe with columns [pose, camera_angle, f1, ..., f1000]
def create_df():
    df = pd.DataFrame(columns=["pose", "camera_angle"])
    for i in range(1, 1001):
        df['f'+str(i)] = -1
    return df

# %%
# Putting the visual featurers of the real hands into a csv
df = create_df()
print(os.getcwd())

model = VGG19(weights='imagenet',include_top=False, input_shape = (128, 128, 3))

processed_files = 0
# load and preprocess image

path, dirs, files = next(os.walk(os.getcwd() + "/poses")) # or "/hand_poses" if cropped automatically
print(path)
print(dirs)
print(files)

for directory in dirs:
    subdir_path = path + "/" + directory
    p, d, files = next(os.walk(subdir_path))
    print(files)
    
    for file in files:
    
        img_path = subdir_path  + "/" + file
        print(img_path)
        img = image.load_img(img_path, target_size=(128, 128))
        x = image.img_to_array(img)
        x = np.expand_dims(x, axis=0)
        x = preprocess_input(x)

        for id_gesture, g in gestures.items():
            if g == directory:
                print(g)
                pose = g

                # predict the class probabilities - extracting the visual features
                preds = model.predict(x)
                p = preds.flatten()

                data = np.insert(p, 0, pose)
                data = np.insert(data, 1, 0)
        
        
                print(df.shape)
                df.loc[len(df)] = data[1:1003]
                df["camera_angle"] = "straight_on"

                print(processed_files)
                processed_files += 1

print(str(processed_files) + " processed files")
print(df.shape)
print(df)

df.to_csv(os.getcwd() + "/data/real-hands.csv")
# Out:
# D:\FINAL_PROJECT_PI4
# D:\FINAL_PROJECT_PI4/poses
# ['fist', 'index', 'jesus', 'l', 'metal', 'palm', 'pinky', 'ronaldinho', 'three', 'two']
# []
# ['0.jpg', '1.jpg', '10.jpg', '11.jpg', '12.jpg', '13.jpg', '14.jpg', '15.jpg', '16.jpg', '17.jpg', '18.jpg', '19.jpg', '2.jpg', '20.jpg', '21.jpg', '22.jpg', '23.jpg', '24.jpg', '25.jpg', '26.jpg', '27.jpg', '28.jpg', '29.jpg', '3.jpg', '30.jpg', '31.jpg', '32.jpg', '33.jpg', '34.jpg', '35.jpg', '36.jpg', '37.jpg', '38.jpg', '39.jpg', '4.jpg', '40.jpg', '41.jpg', '42.jpg', '43.jpg', '44.jpg', '45.jpg', '46.jpg', '47.jpg', '48.jpg', '49.jpg', '5.jpg', '50.jpg', '51.jpg', '52.jpg', '53.jpg', '54.jpg', '55.jpg', '56.jpg', '57.jpg', '58.jpg', '59.jpg', '6.jpg', '60.jpg', '61.jpg', '62.jpg', '63.jpg', '64.jpg', '65.jpg', '66.jpg', '67.jpg', '68.jpg', '69.jpg', '7.jpg', '70.jpg', '71.jpg', '72.jpg', '73.jpg', '74.jpg', '75.jpg', '76.jpg', '77.jpg', '78.jpg', '79.jpg', '8.jpg', '80.jpg', '81.jpg', '82.jpg', '83.jpg', '84.jpg', '85.jpg', '86.jpg', '87.jpg', '88.jpg', '89.jpg', '9.jpg', '90.jpg', '91.jpg', '92.jpg']
# D:\FINAL_PROJECT_PI4/poses/fist/0.jpg
# D:\FINAL_PROJECT_PI4/poses/fist/1.jpg
# D:\FINAL_PROJECT_PI4/poses/fist/10.jpg
# D:\FINAL_PROJECT_PI4/poses/fist/11.jpg
# D:\FINAL_PROJECT_PI4/poses/fist/12.jpg
# D:\FINAL_PROJECT_PI4/poses/fist/13.jpg
# D:\FINAL_PROJECT_PI4/poses/fist/14.jpg
# D:\FINAL_PROJECT_PI4/poses/fist/15.jpg
# D:\FINAL_PROJECT_PI4/poses/fist/16.jpg
# D:\FINAL_PROJECT_PI4/poses/fist/17.jpg
# D:\FINAL_PROJECT_PI4/poses/fist/18.jpg
# D:\FINAL_PROJECT_PI4/poses/fist/19.jpg
# D:\FINAL_PROJECT_PI4/poses/fist/2.jpg
# D:\FINAL_PROJECT_PI4/poses/fist/20.jpg
# D:\FINAL_PROJECT_PI4/poses/fist/21.jpg
# D:\FINAL_PROJECT_PI4/poses/fist/22.jpg
# D:\FINAL_PROJECT_PI4/poses/fist/23.jpg
# D:\FINAL_PROJECT_PI4/poses/fist/24.jpg
# D:\FINAL_PROJECT_PI4/poses/fist/25.jpg
# D:\FINAL_PROJECT_PI4/poses/fist/26.jpg
# D:\FINAL_PROJECT_PI4/poses/fist/27.jpg
# D:\FINAL_PROJECT_PI4/poses/fist/28.jpg
# D:\FINAL_PROJECT_PI4/poses/fist/29.jpg
# D:\FINAL_PROJECT_PI4/poses/fist/3.jpg
# D:\FINAL_PROJECT_PI4/poses/fist/30.jpg
# D:\FINAL_PROJECT_PI4/poses/fist/31.jpg
# D:\FINAL_PROJECT_PI4/poses/fist/32.jpg
# D:\FINAL_PROJECT_PI4/poses/fist/33.jpg
# D:\FINAL_PROJECT_PI4/poses/fist/34.jpg
# D:\FINAL_PROJECT_PI4/poses/fist/35.jpg
# D:\FINAL_PROJECT_PI4/poses/fist/36.jpg
# D:\FINAL_PROJECT_PI4/poses/fist/37.jpg
# D:\FINAL_PROJECT_PI4/poses/fist/38.jpg
# D:\FINAL_PROJECT_PI4/poses/fist/39.jpg
# D:\FINAL_PROJECT_PI4/poses/fist/4.jpg
# D:\FINAL_PROJECT_PI4/poses/fist/40.jpg
# D:\FINAL_PROJECT_PI4/poses/fist/41.jpg
# D:\FINAL_PROJECT_PI4/poses/fist/42.jpg
# D:\FINAL_PROJECT_PI4/poses/fist/43.jpg
# D:\FINAL_PROJECT_PI4/poses/fist/44.jpg
# D:\FINAL_PROJECT_PI4/poses/fist/45.jpg
# D:\FINAL_PROJECT_PI4/poses/fist/46.jpg
# D:\FINAL_PROJECT_PI4/poses/fist/47.jpg
# D:\FINAL_PROJECT_PI4/poses/fist/48.jpg
# D:\FINAL_PROJECT_PI4/poses/fist/49.jpg
# D:\FINAL_PROJECT_PI4/poses/fist/5.jpg
# D:\FINAL_PROJECT_PI4/poses/fist/50.jpg
# D:\FINAL_PROJECT_PI4/poses/fist/51.jpg
# D:\FINAL_PROJECT_PI4/poses/fist/52.jpg
# D:\FINAL_PROJECT_PI4/poses/fist/53.jpg
# D:\FINAL_PROJECT_PI4/poses/fist/54.jpg
# D:\FINAL_PROJECT_PI4/poses/fist/55.jpg
# D:\FINAL_PROJECT_PI4/poses/fist/56.jpg
# D:\FINAL_PROJECT_PI4/poses/fist/57.jpg
# D:\FINAL_PROJECT_PI4/poses/fist/58.jpg
# D:\FINAL_PROJECT_PI4/poses/fist/59.jpg
# D:\FINAL_PROJECT_PI4/poses/fist/6.jpg
# D:\FINAL_PROJECT_PI4/poses/fist/60.jpg
# D:\FINAL_PROJECT_PI4/poses/fist/61.jpg
# D:\FINAL_PROJECT_PI4/poses/fist/62.jpg
# D:\FINAL_PROJECT_PI4/poses/fist/63.jpg
# D:\FINAL_PROJECT_PI4/poses/fist/64.jpg
# D:\FINAL_PROJECT_PI4/poses/fist/65.jpg
# D:\FINAL_PROJECT_PI4/poses/fist/66.jpg
# D:\FINAL_PROJECT_PI4/poses/fist/67.jpg
# D:\FINAL_PROJECT_PI4/poses/fist/68.jpg
# D:\FINAL_PROJECT_PI4/poses/fist/69.jpg
# D:\FINAL_PROJECT_PI4/poses/fist/7.jpg
# D:\FINAL_PROJECT_PI4/poses/fist/70.jpg
# D:\FINAL_PROJECT_PI4/poses/fist/71.jpg
# D:\FINAL_PROJECT_PI4/poses/fist/72.jpg
# D:\FINAL_PROJECT_PI4/poses/fist/73.jpg
# D:\FINAL_PROJECT_PI4/poses/fist/74.jpg
# D:\FINAL_PROJECT_PI4/poses/fist/75.jpg
# D:\FINAL_PROJECT_PI4/poses/fist/76.jpg
# D:\FINAL_PROJECT_PI4/poses/fist/77.jpg
# D:\FINAL_PROJECT_PI4/poses/fist/78.jpg
# D:\FINAL_PROJECT_PI4/poses/fist/79.jpg
# D:\FINAL_PROJECT_PI4/poses/fist/8.jpg
# D:\FINAL_PROJECT_PI4/poses/fist/80.jpg
# D:\FINAL_PROJECT_PI4/poses/fist/81.jpg
# D:\FINAL_PROJECT_PI4/poses/fist/82.jpg
# D:\FINAL_PROJECT_PI4/poses/fist/83.jpg
# D:\FINAL_PROJECT_PI4/poses/fist/84.jpg
# D:\FINAL_PROJECT_PI4/poses/fist/85.jpg
# D:\FINAL_PROJECT_PI4/poses/fist/86.jpg
# D:\FINAL_PROJECT_PI4/poses/fist/87.jpg
# D:\FINAL_PROJECT_PI4/poses/fist/88.jpg
# D:\FINAL_PROJECT_PI4/poses/fist/89.jpg
# D:\FINAL_PROJECT_PI4/poses/fist/9.jpg
# D:\FINAL_PROJECT_PI4/poses/fist/90.jpg
# D:\FINAL_PROJECT_PI4/poses/fist/91.jpg
# D:\FINAL_PROJECT_PI4/poses/fist/92.jpg
# ['100.jpg', '101.jpg', '102.jpg', '103.jpg', '104.jpg', '105.jpg', '106.jpg', '107.jpg', '108.jpg', '109.jpg', '110.jpg', '111.jpg', '112.jpg', '113.jpg', '114.jpg', '115.jpg', '116.jpg', '117.jpg', '118.jpg', '119.jpg', '120.jpg', '121.jpg', '122.jpg', '123.jpg', '124.jpg', '125.jpg', '126.jpg', '127.jpg', '128.jpg', '129.jpg', '130.jpg', '131.jpg', '132.jpg', '133.jpg', '134.jpg', '135.jpg', '136.jpg', '137.jpg', '138.jpg', '139.jpg', '140.jpg', '141.jpg', '142.jpg', '143.jpg', '144.jpg', '145.jpg', '146.jpg', '147.jpg', '148.jpg', '93.jpg', '94.jpg', '95.jpg', '96.jpg', '97.jpg', '98.jpg', '99.jpg']
# D:\FINAL_PROJECT_PI4/poses/index/100.jpg
# D:\FINAL_PROJECT_PI4/poses/index/101.jpg
# D:\FINAL_PROJECT_PI4/poses/index/102.jpg
# D:\FINAL_PROJECT_PI4/poses/index/103.jpg
# D:\FINAL_PROJECT_PI4/poses/index/104.jpg
# D:\FINAL_PROJECT_PI4/poses/index/105.jpg
# D:\FINAL_PROJECT_PI4/poses/index/106.jpg
# D:\FINAL_PROJECT_PI4/poses/index/107.jpg
# D:\FINAL_PROJECT_PI4/poses/index/108.jpg
# D:\FINAL_PROJECT_PI4/poses/index/109.jpg
# D:\FINAL_PROJECT_PI4/poses/index/110.jpg
# D:\FINAL_PROJECT_PI4/poses/index/111.jpg
# D:\FINAL_PROJECT_PI4/poses/index/112.jpg
# D:\FINAL_PROJECT_PI4/poses/index/113.jpg
# D:\FINAL_PROJECT_PI4/poses/index/114.jpg
# D:\FINAL_PROJECT_PI4/poses/index/115.jpg
# D:\FINAL_PROJECT_PI4/poses/index/116.jpg
# D:\FINAL_PROJECT_PI4/poses/index/117.jpg
# D:\FINAL_PROJECT_PI4/poses/index/118.jpg
# D:\FINAL_PROJECT_PI4/poses/index/119.jpg
# D:\FINAL_PROJECT_PI4/poses/index/120.jpg
# D:\FINAL_PROJECT_PI4/poses/index/121.jpg
# D:\FINAL_PROJECT_PI4/poses/index/122.jpg
# D:\FINAL_PROJECT_PI4/poses/index/123.jpg
# D:\FINAL_PROJECT_PI4/poses/index/124.jpg
# D:\FINAL_PROJECT_PI4/poses/index/125.jpg
# D:\FINAL_PROJECT_PI4/poses/index/126.jpg
# D:\FINAL_PROJECT_PI4/poses/index/127.jpg
# D:\FINAL_PROJECT_PI4/poses/index/128.jpg
# D:\FINAL_PROJECT_PI4/poses/index/129.jpg
# D:\FINAL_PROJECT_PI4/poses/index/130.jpg
# D:\FINAL_PROJECT_PI4/poses/index/131.jpg
# D:\FINAL_PROJECT_PI4/poses/index/132.jpg
# D:\FINAL_PROJECT_PI4/poses/index/133.jpg
# D:\FINAL_PROJECT_PI4/poses/index/134.jpg
# D:\FINAL_PROJECT_PI4/poses/index/135.jpg
# D:\FINAL_PROJECT_PI4/poses/index/136.jpg
# D:\FINAL_PROJECT_PI4/poses/index/137.jpg
# D:\FINAL_PROJECT_PI4/poses/index/138.jpg
# D:\FINAL_PROJECT_PI4/poses/index/139.jpg
# D:\FINAL_PROJECT_PI4/poses/index/140.jpg
# D:\FINAL_PROJECT_PI4/poses/index/141.jpg
# D:\FINAL_PROJECT_PI4/poses/index/142.jpg
# D:\FINAL_PROJECT_PI4/poses/index/143.jpg
# D:\FINAL_PROJECT_PI4/poses/index/144.jpg
# D:\FINAL_PROJECT_PI4/poses/index/145.jpg
# D:\FINAL_PROJECT_PI4/poses/index/146.jpg
# D:\FINAL_PROJECT_PI4/poses/index/147.jpg
# D:\FINAL_PROJECT_PI4/poses/index/148.jpg
# D:\FINAL_PROJECT_PI4/poses/index/93.jpg
# D:\FINAL_PROJECT_PI4/poses/index/94.jpg
# D:\FINAL_PROJECT_PI4/poses/index/95.jpg
# D:\FINAL_PROJECT_PI4/poses/index/96.jpg
# D:\FINAL_PROJECT_PI4/poses/index/97.jpg
# D:\FINAL_PROJECT_PI4/poses/index/98.jpg
# D:\FINAL_PROJECT_PI4/poses/index/99.jpg
# ['149.jpg', '150.jpg', '151.jpg', '152.jpg', '153.jpg', '154.jpg', '155.jpg', '156.jpg', '157.jpg', '158.jpg', '159.jpg', '160.jpg', '161.jpg', '162.jpg', '163.jpg', '164.jpg', '165.jpg', '166.jpg', '167.jpg', '168.jpg', '169.jpg', '170.jpg', '171.jpg', '172.jpg', '173.jpg', '174.jpg', '175.jpg', '176.jpg', '177.jpg', '178.jpg', '179.jpg', '180.jpg', '181.jpg', '182.jpg', '183.jpg', '184.jpg', '185.jpg', '186.jpg', '187.jpg', '188.jpg', '189.jpg', '190.jpg', '191.jpg', '192.jpg', '193.jpg', '194.jpg', '195.jpg', '196.jpg', '197.jpg', '198.jpg', '199.jpg', '200.jpg', '201.jpg']
# D:\FINAL_PROJECT_PI4/poses/jesus/149.jpg
# D:\FINAL_PROJECT_PI4/poses/jesus/150.jpg
# D:\FINAL_PROJECT_PI4/poses/jesus/151.jpg
# D:\FINAL_PROJECT_PI4/poses/jesus/152.jpg
# D:\FINAL_PROJECT_PI4/poses/jesus/153.jpg
# D:\FINAL_PROJECT_PI4/poses/jesus/154.jpg
# D:\FINAL_PROJECT_PI4/poses/jesus/155.jpg
# D:\FINAL_PROJECT_PI4/poses/jesus/156.jpg
# D:\FINAL_PROJECT_PI4/poses/jesus/157.jpg
# D:\FINAL_PROJECT_PI4/poses/jesus/158.jpg
# D:\FINAL_PROJECT_PI4/poses/jesus/159.jpg
# D:\FINAL_PROJECT_PI4/poses/jesus/160.jpg
# D:\FINAL_PROJECT_PI4/poses/jesus/161.jpg
# D:\FINAL_PROJECT_PI4/poses/jesus/162.jpg
# D:\FINAL_PROJECT_PI4/poses/jesus/163.jpg
# D:\FINAL_PROJECT_PI4/poses/jesus/164.jpg
# D:\FINAL_PROJECT_PI4/poses/jesus/165.jpg
# D:\FINAL_PROJECT_PI4/poses/jesus/166.jpg
# D:\FINAL_PROJECT_PI4/poses/jesus/167.jpg
# D:\FINAL_PROJECT_PI4/poses/jesus/168.jpg
# D:\FINAL_PROJECT_PI4/poses/jesus/169.jpg
# D:\FINAL_PROJECT_PI4/poses/jesus/170.jpg
# D:\FINAL_PROJECT_PI4/poses/jesus/171.jpg
# D:\FINAL_PROJECT_PI4/poses/jesus/172.jpg
# D:\FINAL_PROJECT_PI4/poses/jesus/173.jpg
# D:\FINAL_PROJECT_PI4/poses/jesus/174.jpg
# D:\FINAL_PROJECT_PI4/poses/jesus/175.jpg
# D:\FINAL_PROJECT_PI4/poses/jesus/176.jpg
# D:\FINAL_PROJECT_PI4/poses/jesus/177.jpg
# D:\FINAL_PROJECT_PI4/poses/jesus/178.jpg
# D:\FINAL_PROJECT_PI4/poses/jesus/179.jpg
# D:\FINAL_PROJECT_PI4/poses/jesus/180.jpg
# D:\FINAL_PROJECT_PI4/poses/jesus/181.jpg
# D:\FINAL_PROJECT_PI4/poses/jesus/182.jpg
# D:\FINAL_PROJECT_PI4/poses/jesus/183.jpg
# D:\FINAL_PROJECT_PI4/poses/jesus/184.jpg
# D:\FINAL_PROJECT_PI4/poses/jesus/185.jpg
# D:\FINAL_PROJECT_PI4/poses/jesus/186.jpg
# D:\FINAL_PROJECT_PI4/poses/jesus/187.jpg
# D:\FINAL_PROJECT_PI4/poses/jesus/188.jpg
# D:\FINAL_PROJECT_PI4/poses/jesus/189.jpg
# D:\FINAL_PROJECT_PI4/poses/jesus/190.jpg
# D:\FINAL_PROJECT_PI4/poses/jesus/191.jpg
# D:\FINAL_PROJECT_PI4/poses/jesus/192.jpg
# D:\FINAL_PROJECT_PI4/poses/jesus/193.jpg
# D:\FINAL_PROJECT_PI4/poses/jesus/194.jpg
# D:\FINAL_PROJECT_PI4/poses/jesus/195.jpg
# D:\FINAL_PROJECT_PI4/poses/jesus/196.jpg
# D:\FINAL_PROJECT_PI4/poses/jesus/197.jpg
# D:\FINAL_PROJECT_PI4/poses/jesus/198.jpg
# D:\FINAL_PROJECT_PI4/poses/jesus/199.jpg
# D:\FINAL_PROJECT_PI4/poses/jesus/200.jpg
# D:\FINAL_PROJECT_PI4/poses/jesus/201.jpg
# ['202.jpg', '203.jpg', '204.jpg', '205.jpg', '206.jpg', '207.jpg', '208.jpg', '209.jpg', '210.jpg', '211.jpg', '212.jpg', '213.jpg', '214.jpg', '215.jpg', '216.jpg', '217.jpg', '218.jpg', '219.jpg', '220.jpg', '221.jpg', '222.jpg', '223.jpg', '224.jpg', '225.jpg', '226.jpg', '227.jpg', '228.jpg', '229.jpg', '230.jpg', '231.jpg', '232.jpg', '233.jpg', '234.jpg', '235.jpg', '236.jpg', '237.jpg', '238.jpg', '239.jpg', '240.jpg', '241.jpg', '242.jpg', '243.jpg', '244.jpg', '245.jpg', '246.jpg', '247.jpg', '248.jpg', '249.jpg', '250.jpg', '251.jpg', '252.jpg', '253.jpg', '254.jpg', '255.jpg', '256.jpg', '257.jpg', '258.jpg', '259.jpg', '260.jpg', '261.jpg', '262.jpg', '263.jpg', '264.jpg', '265.jpg', '266.jpg']
# D:\FINAL_PROJECT_PI4/poses/l/202.jpg
# D:\FINAL_PROJECT_PI4/poses/l/203.jpg
# D:\FINAL_PROJECT_PI4/poses/l/204.jpg
# D:\FINAL_PROJECT_PI4/poses/l/205.jpg
# D:\FINAL_PROJECT_PI4/poses/l/206.jpg
# D:\FINAL_PROJECT_PI4/poses/l/207.jpg
# D:\FINAL_PROJECT_PI4/poses/l/208.jpg
# D:\FINAL_PROJECT_PI4/poses/l/209.jpg
# D:\FINAL_PROJECT_PI4/poses/l/210.jpg
# D:\FINAL_PROJECT_PI4/poses/l/211.jpg
# D:\FINAL_PROJECT_PI4/poses/l/212.jpg
# D:\FINAL_PROJECT_PI4/poses/l/213.jpg
# D:\FINAL_PROJECT_PI4/poses/l/214.jpg
# D:\FINAL_PROJECT_PI4/poses/l/215.jpg
# D:\FINAL_PROJECT_PI4/poses/l/216.jpg
# D:\FINAL_PROJECT_PI4/poses/l/217.jpg
# D:\FINAL_PROJECT_PI4/poses/l/218.jpg
# D:\FINAL_PROJECT_PI4/poses/l/219.jpg
# D:\FINAL_PROJECT_PI4/poses/l/220.jpg
# D:\FINAL_PROJECT_PI4/poses/l/221.jpg
# D:\FINAL_PROJECT_PI4/poses/l/222.jpg
# D:\FINAL_PROJECT_PI4/poses/l/223.jpg
# D:\FINAL_PROJECT_PI4/poses/l/224.jpg
# D:\FINAL_PROJECT_PI4/poses/l/225.jpg
# D:\FINAL_PROJECT_PI4/poses/l/226.jpg
# D:\FINAL_PROJECT_PI4/poses/l/227.jpg
# D:\FINAL_PROJECT_PI4/poses/l/228.jpg
# D:\FINAL_PROJECT_PI4/poses/l/229.jpg
# D:\FINAL_PROJECT_PI4/poses/l/230.jpg
# D:\FINAL_PROJECT_PI4/poses/l/231.jpg
# D:\FINAL_PROJECT_PI4/poses/l/232.jpg
# D:\FINAL_PROJECT_PI4/poses/l/233.jpg
# D:\FINAL_PROJECT_PI4/poses/l/234.jpg
# D:\FINAL_PROJECT_PI4/poses/l/235.jpg
# D:\FINAL_PROJECT_PI4/poses/l/236.jpg
# D:\FINAL_PROJECT_PI4/poses/l/237.jpg
# D:\FINAL_PROJECT_PI4/poses/l/238.jpg
# D:\FINAL_PROJECT_PI4/poses/l/239.jpg
# D:\FINAL_PROJECT_PI4/poses/l/240.jpg
# D:\FINAL_PROJECT_PI4/poses/l/241.jpg
# D:\FINAL_PROJECT_PI4/poses/l/242.jpg
# D:\FINAL_PROJECT_PI4/poses/l/243.jpg
# D:\FINAL_PROJECT_PI4/poses/l/244.jpg
# D:\FINAL_PROJECT_PI4/poses/l/245.jpg
# D:\FINAL_PROJECT_PI4/poses/l/246.jpg
# D:\FINAL_PROJECT_PI4/poses/l/247.jpg
# D:\FINAL_PROJECT_PI4/poses/l/248.jpg
# D:\FINAL_PROJECT_PI4/poses/l/249.jpg
# D:\FINAL_PROJECT_PI4/poses/l/250.jpg
# D:\FINAL_PROJECT_PI4/poses/l/251.jpg
# D:\FINAL_PROJECT_PI4/poses/l/252.jpg
# D:\FINAL_PROJECT_PI4/poses/l/253.jpg
# D:\FINAL_PROJECT_PI4/poses/l/254.jpg
# D:\FINAL_PROJECT_PI4/poses/l/255.jpg
# D:\FINAL_PROJECT_PI4/poses/l/256.jpg
# D:\FINAL_PROJECT_PI4/poses/l/257.jpg
# D:\FINAL_PROJECT_PI4/poses/l/258.jpg
# D:\FINAL_PROJECT_PI4/poses/l/259.jpg
# D:\FINAL_PROJECT_PI4/poses/l/260.jpg
# D:\FINAL_PROJECT_PI4/poses/l/261.jpg
# D:\FINAL_PROJECT_PI4/poses/l/262.jpg
# D:\FINAL_PROJECT_PI4/poses/l/263.jpg
# D:\FINAL_PROJECT_PI4/poses/l/264.jpg
# D:\FINAL_PROJECT_PI4/poses/l/265.jpg
# D:\FINAL_PROJECT_PI4/poses/l/266.jpg
# ['267.jpg', '268.jpg', '269.jpg', '270.jpg', '271.jpg', '272.jpg', '273.jpg', '274.jpg', '275.jpg', '276.jpg', '277.jpg', '278.jpg', '279.jpg', '280.jpg', '281.jpg', '282.jpg', '283.jpg', '284.jpg', '285.jpg', '286.jpg', '287.jpg', '288.jpg', '289.jpg', '290.jpg', '291.jpg', '292.jpg', '293.jpg', '294.jpg', '295.jpg', '296.jpg', '297.jpg', '298.jpg', '299.jpg', '300.jpg', '301.jpg', '302.jpg', '303.jpg', '304.jpg', '305.jpg', '306.jpg', '307.jpg', '308.jpg', '309.jpg', '310.jpg', '311.jpg', '312.jpg', '313.jpg', '314.jpg', '315.jpg', '316.jpg', '317.jpg', '318.jpg', '319.jpg', '320.jpg', '321.jpg', '322.jpg', '323.jpg', '324.jpg', '325.jpg', '326.jpg', '327.jpg', '328.jpg', '329.jpg', '330.jpg', '331.jpg', '332.jpg', '333.jpg', '334.jpg', '335.jpg', '336.jpg', '337.jpg', '338.jpg', '339.jpg', '340.jpg']
# D:\FINAL_PROJECT_PI4/poses/metal/267.jpg
# D:\FINAL_PROJECT_PI4/poses/metal/268.jpg
# D:\FINAL_PROJECT_PI4/poses/metal/269.jpg
# D:\FINAL_PROJECT_PI4/poses/metal/270.jpg
# D:\FINAL_PROJECT_PI4/poses/metal/271.jpg
# D:\FINAL_PROJECT_PI4/poses/metal/272.jpg
# D:\FINAL_PROJECT_PI4/poses/metal/273.jpg
# D:\FINAL_PROJECT_PI4/poses/metal/274.jpg
# D:\FINAL_PROJECT_PI4/poses/metal/275.jpg
# D:\FINAL_PROJECT_PI4/poses/metal/276.jpg
# D:\FINAL_PROJECT_PI4/poses/metal/277.jpg
# D:\FINAL_PROJECT_PI4/poses/metal/278.jpg
# D:\FINAL_PROJECT_PI4/poses/metal/279.jpg
# D:\FINAL_PROJECT_PI4/poses/metal/280.jpg
# D:\FINAL_PROJECT_PI4/poses/metal/281.jpg
# D:\FINAL_PROJECT_PI4/poses/metal/282.jpg
# D:\FINAL_PROJECT_PI4/poses/metal/283.jpg
# D:\FINAL_PROJECT_PI4/poses/metal/284.jpg
# D:\FINAL_PROJECT_PI4/poses/metal/285.jpg
# D:\FINAL_PROJECT_PI4/poses/metal/286.jpg
# D:\FINAL_PROJECT_PI4/poses/metal/287.jpg
# D:\FINAL_PROJECT_PI4/poses/metal/288.jpg
# D:\FINAL_PROJECT_PI4/poses/metal/289.jpg
# D:\FINAL_PROJECT_PI4/poses/metal/290.jpg
# D:\FINAL_PROJECT_PI4/poses/metal/291.jpg
# D:\FINAL_PROJECT_PI4/poses/metal/292.jpg
# D:\FINAL_PROJECT_PI4/poses/metal/293.jpg
# D:\FINAL_PROJECT_PI4/poses/metal/294.jpg
# D:\FINAL_PROJECT_PI4/poses/metal/295.jpg
# D:\FINAL_PROJECT_PI4/poses/metal/296.jpg
# D:\FINAL_PROJECT_PI4/poses/metal/297.jpg
# D:\FINAL_PROJECT_PI4/poses/metal/298.jpg
# D:\FINAL_PROJECT_PI4/poses/metal/299.jpg
# D:\FINAL_PROJECT_PI4/poses/metal/300.jpg
# D:\FINAL_PROJECT_PI4/poses/metal/301.jpg
# D:\FINAL_PROJECT_PI4/poses/metal/302.jpg
# D:\FINAL_PROJECT_PI4/poses/metal/303.jpg
# D:\FINAL_PROJECT_PI4/poses/metal/304.jpg
# D:\FINAL_PROJECT_PI4/poses/metal/305.jpg
# D:\FINAL_PROJECT_PI4/poses/metal/306.jpg
# D:\FINAL_PROJECT_PI4/poses/metal/307.jpg
# D:\FINAL_PROJECT_PI4/poses/metal/308.jpg
# D:\FINAL_PROJECT_PI4/poses/metal/309.jpg
# D:\FINAL_PROJECT_PI4/poses/metal/310.jpg
# D:\FINAL_PROJECT_PI4/poses/metal/311.jpg
# D:\FINAL_PROJECT_PI4/poses/metal/312.jpg
# D:\FINAL_PROJECT_PI4/poses/metal/313.jpg
# D:\FINAL_PROJECT_PI4/poses/metal/314.jpg
# D:\FINAL_PROJECT_PI4/poses/metal/315.jpg
# D:\FINAL_PROJECT_PI4/poses/metal/316.jpg
# D:\FINAL_PROJECT_PI4/poses/metal/317.jpg
# D:\FINAL_PROJECT_PI4/poses/metal/318.jpg
# D:\FINAL_PROJECT_PI4/poses/metal/319.jpg
# D:\FINAL_PROJECT_PI4/poses/metal/320.jpg
# D:\FINAL_PROJECT_PI4/poses/metal/321.jpg
# D:\FINAL_PROJECT_PI4/poses/metal/322.jpg
# D:\FINAL_PROJECT_PI4/poses/metal/323.jpg
# D:\FINAL_PROJECT_PI4/poses/metal/324.jpg
# D:\FINAL_PROJECT_PI4/poses/metal/325.jpg
# D:\FINAL_PROJECT_PI4/poses/metal/326.jpg
# D:\FINAL_PROJECT_PI4/poses/metal/327.jpg
# D:\FINAL_PROJECT_PI4/poses/metal/328.jpg
# D:\FINAL_PROJECT_PI4/poses/metal/329.jpg
# D:\FINAL_PROJECT_PI4/poses/metal/330.jpg
# D:\FINAL_PROJECT_PI4/poses/metal/331.jpg
# D:\FINAL_PROJECT_PI4/poses/metal/332.jpg
# D:\FINAL_PROJECT_PI4/poses/metal/333.jpg
# D:\FINAL_PROJECT_PI4/poses/metal/334.jpg
# D:\FINAL_PROJECT_PI4/poses/metal/335.jpg
# D:\FINAL_PROJECT_PI4/poses/metal/336.jpg
# D:\FINAL_PROJECT_PI4/poses/metal/337.jpg
# D:\FINAL_PROJECT_PI4/poses/metal/338.jpg
# D:\FINAL_PROJECT_PI4/poses/metal/339.jpg
# D:\FINAL_PROJECT_PI4/poses/metal/340.jpg
# ['341.jpg', '342.jpg', '343.jpg', '344.jpg', '345.jpg', '346.jpg', '347.jpg', '348.jpg', '349.jpg', '350.jpg', '351.jpg', '352.jpg', '353.jpg', '354.jpg', '355.jpg', '356.jpg', '357.jpg', '358.jpg', '359.jpg', '360.jpg', '361.jpg', '362.jpg', '363.jpg', '364.jpg', '365.jpg', '366.jpg', '367.jpg', '368.jpg', '369.jpg', '370.jpg', '371.jpg', '372.jpg', '373.jpg', '374.jpg', '375.jpg', '376.jpg', '377.jpg', '378.jpg', '379.jpg', '380.jpg', '381.jpg', '382.jpg', '383.jpg', '384.jpg', '385.jpg', '386.jpg', '387.jpg', '388.jpg', '389.jpg', '390.jpg', '391.jpg', '392.jpg', '393.jpg', '394.jpg', '395.jpg', '396.jpg', '397.jpg', '398.jpg', '399.jpg', '400.jpg', '401.jpg', '402.jpg', '403.jpg', '404.jpg', '405.jpg', '406.jpg', '407.jpg', '408.jpg', '409.jpg', '410.jpg', '411.jpg', '412.jpg', '413.jpg', '414.jpg', '415.jpg', '416.jpg', '417.jpg', '418.jpg', '419.jpg', '420.jpg', '421.jpg', '422.jpg', '423.jpg', '424.jpg', '425.jpg', '426.jpg', '427.jpg', '428.jpg', '429.jpg', '430.jpg', '431.jpg', '432.jpg', '433.jpg', '434.jpg', '435.jpg', '436.jpg', '437.jpg', '438.jpg', '439.jpg', '440.jpg', '441.jpg', '442.jpg', '443.jpg', '444.jpg']
# D:\FINAL_PROJECT_PI4/poses/palm/341.jpg
# D:\FINAL_PROJECT_PI4/poses/palm/342.jpg
# D:\FINAL_PROJECT_PI4/poses/palm/343.jpg
# D:\FINAL_PROJECT_PI4/poses/palm/344.jpg
# D:\FINAL_PROJECT_PI4/poses/palm/345.jpg
# D:\FINAL_PROJECT_PI4/poses/palm/346.jpg
# D:\FINAL_PROJECT_PI4/poses/palm/347.jpg
# D:\FINAL_PROJECT_PI4/poses/palm/348.jpg
# D:\FINAL_PROJECT_PI4/poses/palm/349.jpg
# D:\FINAL_PROJECT_PI4/poses/palm/350.jpg
# D:\FINAL_PROJECT_PI4/poses/palm/351.jpg
# D:\FINAL_PROJECT_PI4/poses/palm/352.jpg
# D:\FINAL_PROJECT_PI4/poses/palm/353.jpg
# D:\FINAL_PROJECT_PI4/poses/palm/354.jpg
# D:\FINAL_PROJECT_PI4/poses/palm/355.jpg
# D:\FINAL_PROJECT_PI4/poses/palm/356.jpg
# D:\FINAL_PROJECT_PI4/poses/palm/357.jpg
# D:\FINAL_PROJECT_PI4/poses/palm/358.jpg
# D:\FINAL_PROJECT_PI4/poses/palm/359.jpg
# D:\FINAL_PROJECT_PI4/poses/palm/360.jpg
# D:\FINAL_PROJECT_PI4/poses/palm/361.jpg
# D:\FINAL_PROJECT_PI4/poses/palm/362.jpg
# D:\FINAL_PROJECT_PI4/poses/palm/363.jpg
# D:\FINAL_PROJECT_PI4/poses/palm/364.jpg
# D:\FINAL_PROJECT_PI4/poses/palm/365.jpg
# D:\FINAL_PROJECT_PI4/poses/palm/366.jpg
# D:\FINAL_PROJECT_PI4/poses/palm/367.jpg
# D:\FINAL_PROJECT_PI4/poses/palm/368.jpg
# D:\FINAL_PROJECT_PI4/poses/palm/369.jpg
# D:\FINAL_PROJECT_PI4/poses/palm/370.jpg
# D:\FINAL_PROJECT_PI4/poses/palm/371.jpg
# D:\FINAL_PROJECT_PI4/poses/palm/372.jpg
# D:\FINAL_PROJECT_PI4/poses/palm/373.jpg
# D:\FINAL_PROJECT_PI4/poses/palm/374.jpg
# D:\FINAL_PROJECT_PI4/poses/palm/375.jpg
# D:\FINAL_PROJECT_PI4/poses/palm/376.jpg
# D:\FINAL_PROJECT_PI4/poses/palm/377.jpg
# D:\FINAL_PROJECT_PI4/poses/palm/378.jpg
# D:\FINAL_PROJECT_PI4/poses/palm/379.jpg
# D:\FINAL_PROJECT_PI4/poses/palm/380.jpg
# D:\FINAL_PROJECT_PI4/poses/palm/381.jpg
# D:\FINAL_PROJECT_PI4/poses/palm/382.jpg
# D:\FINAL_PROJECT_PI4/poses/palm/383.jpg
# D:\FINAL_PROJECT_PI4/poses/palm/384.jpg
# D:\FINAL_PROJECT_PI4/poses/palm/385.jpg
# D:\FINAL_PROJECT_PI4/poses/palm/386.jpg
# D:\FINAL_PROJECT_PI4/poses/palm/387.jpg
# D:\FINAL_PROJECT_PI4/poses/palm/388.jpg
# D:\FINAL_PROJECT_PI4/poses/palm/389.jpg
# D:\FINAL_PROJECT_PI4/poses/palm/390.jpg
# D:\FINAL_PROJECT_PI4/poses/palm/391.jpg
# D:\FINAL_PROJECT_PI4/poses/palm/392.jpg
# D:\FINAL_PROJECT_PI4/poses/palm/393.jpg
# D:\FINAL_PROJECT_PI4/poses/palm/394.jpg
# D:\FINAL_PROJECT_PI4/poses/palm/395.jpg
# D:\FINAL_PROJECT_PI4/poses/palm/396.jpg
# D:\FINAL_PROJECT_PI4/poses/palm/397.jpg
# D:\FINAL_PROJECT_PI4/poses/palm/398.jpg
# D:\FINAL_PROJECT_PI4/poses/palm/399.jpg
# D:\FINAL_PROJECT_PI4/poses/palm/400.jpg
# D:\FINAL_PROJECT_PI4/poses/palm/401.jpg
# D:\FINAL_PROJECT_PI4/poses/palm/402.jpg
# D:\FINAL_PROJECT_PI4/poses/palm/403.jpg
# D:\FINAL_PROJECT_PI4/poses/palm/404.jpg
# D:\FINAL_PROJECT_PI4/poses/palm/405.jpg
# D:\FINAL_PROJECT_PI4/poses/palm/406.jpg
# D:\FINAL_PROJECT_PI4/poses/palm/407.jpg
# D:\FINAL_PROJECT_PI4/poses/palm/408.jpg
# D:\FINAL_PROJECT_PI4/poses/palm/409.jpg
# D:\FINAL_PROJECT_PI4/poses/palm/410.jpg
# D:\FINAL_PROJECT_PI4/poses/palm/411.jpg
# D:\FINAL_PROJECT_PI4/poses/palm/412.jpg
# D:\FINAL_PROJECT_PI4/poses/palm/413.jpg
# D:\FINAL_PROJECT_PI4/poses/palm/414.jpg
# D:\FINAL_PROJECT_PI4/poses/palm/415.jpg
# D:\FINAL_PROJECT_PI4/poses/palm/416.jpg
# D:\FINAL_PROJECT_PI4/poses/palm/417.jpg
# D:\FINAL_PROJECT_PI4/poses/palm/418.jpg
# D:\FINAL_PROJECT_PI4/poses/palm/419.jpg
# D:\FINAL_PROJECT_PI4/poses/palm/420.jpg
# D:\FINAL_PROJECT_PI4/poses/palm/421.jpg
# D:\FINAL_PROJECT_PI4/poses/palm/422.jpg
# D:\FINAL_PROJECT_PI4/poses/palm/423.jpg
# D:\FINAL_PROJECT_PI4/poses/palm/424.jpg
# D:\FINAL_PROJECT_PI4/poses/palm/425.jpg
# D:\FINAL_PROJECT_PI4/poses/palm/426.jpg
# D:\FINAL_PROJECT_PI4/poses/palm/427.jpg
# D:\FINAL_PROJECT_PI4/poses/palm/428.jpg
# D:\FINAL_PROJECT_PI4/poses/palm/429.jpg
# D:\FINAL_PROJECT_PI4/poses/palm/430.jpg
# D:\FINAL_PROJECT_PI4/poses/palm/431.jpg
# D:\FINAL_PROJECT_PI4/poses/palm/432.jpg
# D:\FINAL_PROJECT_PI4/poses/palm/433.jpg
# D:\FINAL_PROJECT_PI4/poses/palm/434.jpg
# D:\FINAL_PROJECT_PI4/poses/palm/435.jpg
# D:\FINAL_PROJECT_PI4/poses/palm/436.jpg
# D:\FINAL_PROJECT_PI4/poses/palm/437.jpg
# D:\FINAL_PROJECT_PI4/poses/palm/438.jpg
# D:\FINAL_PROJECT_PI4/poses/palm/439.jpg
# D:\FINAL_PROJECT_PI4/poses/palm/440.jpg
# D:\FINAL_PROJECT_PI4/poses/palm/441.jpg
# D:\FINAL_PROJECT_PI4/poses/palm/442.jpg
# D:\FINAL_PROJECT_PI4/poses/palm/443.jpg
# D:\FINAL_PROJECT_PI4/poses/palm/444.jpg
# ['445.jpg', '446.jpg', '447.jpg', '448.jpg', '449.jpg', '450.jpg', '451.jpg', '452.jpg', '453.jpg', '454.jpg', '455.jpg', '456.jpg', '457.jpg', '458.jpg', '459.jpg', '460.jpg', '461.jpg', '462.jpg', '463.jpg', '464.jpg', '465.jpg', '466.jpg', '467.jpg', '468.jpg', '469.jpg', '470.jpg', '471.jpg', '472.jpg', '473.jpg', '474.jpg', '475.jpg', '476.jpg', '477.jpg', '478.jpg', '479.jpg', '480.jpg', '481.jpg', '482.jpg', '483.jpg', '484.jpg', '485.jpg', '486.jpg', '487.jpg', '488.jpg', '489.jpg', '490.jpg', '491.jpg', '492.jpg', '493.jpg', '494.jpg', '495.jpg', '496.jpg', '497.jpg', '498.jpg', '499.jpg', '500.jpg', '501.jpg', '502.jpg', '503.jpg', '504.jpg', '505.jpg', '506.jpg', '507.jpg', '508.jpg', '509.jpg', '510.jpg', '511.jpg', '512.jpg', '513.jpg', '514.jpg', '515.jpg', '516.jpg', '517.jpg']
# D:\FINAL_PROJECT_PI4/poses/pinky/445.jpg
# D:\FINAL_PROJECT_PI4/poses/pinky/446.jpg
# D:\FINAL_PROJECT_PI4/poses/pinky/447.jpg
# D:\FINAL_PROJECT_PI4/poses/pinky/448.jpg
# D:\FINAL_PROJECT_PI4/poses/pinky/449.jpg
# D:\FINAL_PROJECT_PI4/poses/pinky/450.jpg
# D:\FINAL_PROJECT_PI4/poses/pinky/451.jpg
# D:\FINAL_PROJECT_PI4/poses/pinky/452.jpg
# D:\FINAL_PROJECT_PI4/poses/pinky/453.jpg
# D:\FINAL_PROJECT_PI4/poses/pinky/454.jpg
# D:\FINAL_PROJECT_PI4/poses/pinky/455.jpg
# D:\FINAL_PROJECT_PI4/poses/pinky/456.jpg
# D:\FINAL_PROJECT_PI4/poses/pinky/457.jpg
# D:\FINAL_PROJECT_PI4/poses/pinky/458.jpg
# D:\FINAL_PROJECT_PI4/poses/pinky/459.jpg
# D:\FINAL_PROJECT_PI4/poses/pinky/460.jpg
# D:\FINAL_PROJECT_PI4/poses/pinky/461.jpg
# D:\FINAL_PROJECT_PI4/poses/pinky/462.jpg
# D:\FINAL_PROJECT_PI4/poses/pinky/463.jpg
# D:\FINAL_PROJECT_PI4/poses/pinky/464.jpg
# D:\FINAL_PROJECT_PI4/poses/pinky/465.jpg
# D:\FINAL_PROJECT_PI4/poses/pinky/466.jpg
# D:\FINAL_PROJECT_PI4/poses/pinky/467.jpg
# D:\FINAL_PROJECT_PI4/poses/pinky/468.jpg
# D:\FINAL_PROJECT_PI4/poses/pinky/469.jpg
# D:\FINAL_PROJECT_PI4/poses/pinky/470.jpg
# D:\FINAL_PROJECT_PI4/poses/pinky/471.jpg
# D:\FINAL_PROJECT_PI4/poses/pinky/472.jpg
# D:\FINAL_PROJECT_PI4/poses/pinky/473.jpg
# D:\FINAL_PROJECT_PI4/poses/pinky/474.jpg
# D:\FINAL_PROJECT_PI4/poses/pinky/475.jpg
# D:\FINAL_PROJECT_PI4/poses/pinky/476.jpg
# D:\FINAL_PROJECT_PI4/poses/pinky/477.jpg
# D:\FINAL_PROJECT_PI4/poses/pinky/478.jpg
# D:\FINAL_PROJECT_PI4/poses/pinky/479.jpg
# D:\FINAL_PROJECT_PI4/poses/pinky/480.jpg
# D:\FINAL_PROJECT_PI4/poses/pinky/481.jpg
# D:\FINAL_PROJECT_PI4/poses/pinky/482.jpg
# D:\FINAL_PROJECT_PI4/poses/pinky/483.jpg
# D:\FINAL_PROJECT_PI4/poses/pinky/484.jpg
# D:\FINAL_PROJECT_PI4/poses/pinky/485.jpg
# D:\FINAL_PROJECT_PI4/poses/pinky/486.jpg
# D:\FINAL_PROJECT_PI4/poses/pinky/487.jpg
# D:\FINAL_PROJECT_PI4/poses/pinky/488.jpg
# D:\FINAL_PROJECT_PI4/poses/pinky/489.jpg
# D:\FINAL_PROJECT_PI4/poses/pinky/490.jpg
# D:\FINAL_PROJECT_PI4/poses/pinky/491.jpg
# D:\FINAL_PROJECT_PI4/poses/pinky/492.jpg
# D:\FINAL_PROJECT_PI4/poses/pinky/493.jpg
# D:\FINAL_PROJECT_PI4/poses/pinky/494.jpg
# D:\FINAL_PROJECT_PI4/poses/pinky/495.jpg
# D:\FINAL_PROJECT_PI4/poses/pinky/496.jpg
# D:\FINAL_PROJECT_PI4/poses/pinky/497.jpg
# D:\FINAL_PROJECT_PI4/poses/pinky/498.jpg
# D:\FINAL_PROJECT_PI4/poses/pinky/499.jpg
# D:\FINAL_PROJECT_PI4/poses/pinky/500.jpg
# D:\FINAL_PROJECT_PI4/poses/pinky/501.jpg
# D:\FINAL_PROJECT_PI4/poses/pinky/502.jpg
# D:\FINAL_PROJECT_PI4/poses/pinky/503.jpg
# D:\FINAL_PROJECT_PI4/poses/pinky/504.jpg
# D:\FINAL_PROJECT_PI4/poses/pinky/505.jpg
# D:\FINAL_PROJECT_PI4/poses/pinky/506.jpg
# D:\FINAL_PROJECT_PI4/poses/pinky/507.jpg
# D:\FINAL_PROJECT_PI4/poses/pinky/508.jpg
# D:\FINAL_PROJECT_PI4/poses/pinky/509.jpg
# D:\FINAL_PROJECT_PI4/poses/pinky/510.jpg
# D:\FINAL_PROJECT_PI4/poses/pinky/511.jpg
# D:\FINAL_PROJECT_PI4/poses/pinky/512.jpg
# D:\FINAL_PROJECT_PI4/poses/pinky/513.jpg
# D:\FINAL_PROJECT_PI4/poses/pinky/514.jpg
# D:\FINAL_PROJECT_PI4/poses/pinky/515.jpg
# D:\FINAL_PROJECT_PI4/poses/pinky/516.jpg
# D:\FINAL_PROJECT_PI4/poses/pinky/517.jpg
# ['518.jpg', '519.jpg', '520.jpg', '521.jpg', '522.jpg', '523.jpg', '524.jpg', '525.jpg', '526.jpg', '527.jpg', '528.jpg', '529.jpg', '530.jpg', '531.jpg', '532.jpg', '533.jpg', '534.jpg', '535.jpg', '536.jpg', '537.jpg', '538.jpg', '539.jpg', '540.jpg', '541.jpg', '542.jpg', '543.jpg', '544.jpg', '545.jpg', '546.jpg', '547.jpg', '548.jpg', '549.jpg', '550.jpg', '551.jpg', '552.jpg', '553.jpg', '554.jpg', '555.jpg', '556.jpg', '557.jpg', '558.jpg', '559.jpg', '560.jpg', '561.jpg', '562.jpg', '563.jpg', '564.jpg', '565.jpg', '566.jpg', '567.jpg', '568.jpg', '569.jpg', '570.jpg', '571.jpg', '572.jpg', '573.jpg', '574.jpg', '575.jpg', '576.jpg', '577.jpg', '578.jpg', '579.jpg', '580.jpg', '581.jpg', '582.jpg', '583.jpg', '584.jpg', '585.jpg', '586.jpg', '587.jpg', '588.jpg', '589.jpg', '590.jpg', '591.jpg', '592.jpg', '593.jpg', '594.jpg', '595.jpg', '596.jpg']
# D:\FINAL_PROJECT_PI4/poses/ronaldinho/518.jpg
# D:\FINAL_PROJECT_PI4/poses/ronaldinho/519.jpg
# D:\FINAL_PROJECT_PI4/poses/ronaldinho/520.jpg
# D:\FINAL_PROJECT_PI4/poses/ronaldinho/521.jpg
# D:\FINAL_PROJECT_PI4/poses/ronaldinho/522.jpg
# D:\FINAL_PROJECT_PI4/poses/ronaldinho/523.jpg
# D:\FINAL_PROJECT_PI4/poses/ronaldinho/524.jpg
# D:\FINAL_PROJECT_PI4/poses/ronaldinho/525.jpg
# D:\FINAL_PROJECT_PI4/poses/ronaldinho/526.jpg
# D:\FINAL_PROJECT_PI4/poses/ronaldinho/527.jpg
# D:\FINAL_PROJECT_PI4/poses/ronaldinho/528.jpg
# D:\FINAL_PROJECT_PI4/poses/ronaldinho/529.jpg
# D:\FINAL_PROJECT_PI4/poses/ronaldinho/530.jpg
# D:\FINAL_PROJECT_PI4/poses/ronaldinho/531.jpg
# D:\FINAL_PROJECT_PI4/poses/ronaldinho/532.jpg
# D:\FINAL_PROJECT_PI4/poses/ronaldinho/533.jpg
# D:\FINAL_PROJECT_PI4/poses/ronaldinho/534.jpg
# D:\FINAL_PROJECT_PI4/poses/ronaldinho/535.jpg
# D:\FINAL_PROJECT_PI4/poses/ronaldinho/536.jpg
# D:\FINAL_PROJECT_PI4/poses/ronaldinho/537.jpg
# D:\FINAL_PROJECT_PI4/poses/ronaldinho/538.jpg
# D:\FINAL_PROJECT_PI4/poses/ronaldinho/539.jpg
# D:\FINAL_PROJECT_PI4/poses/ronaldinho/540.jpg
# D:\FINAL_PROJECT_PI4/poses/ronaldinho/541.jpg
# D:\FINAL_PROJECT_PI4/poses/ronaldinho/542.jpg
# D:\FINAL_PROJECT_PI4/poses/ronaldinho/543.jpg
# D:\FINAL_PROJECT_PI4/poses/ronaldinho/544.jpg
# D:\FINAL_PROJECT_PI4/poses/ronaldinho/545.jpg
# D:\FINAL_PROJECT_PI4/poses/ronaldinho/546.jpg
# D:\FINAL_PROJECT_PI4/poses/ronaldinho/547.jpg
# D:\FINAL_PROJECT_PI4/poses/ronaldinho/548.jpg
# D:\FINAL_PROJECT_PI4/poses/ronaldinho/549.jpg
# D:\FINAL_PROJECT_PI4/poses/ronaldinho/550.jpg
# D:\FINAL_PROJECT_PI4/poses/ronaldinho/551.jpg
# D:\FINAL_PROJECT_PI4/poses/ronaldinho/552.jpg
# D:\FINAL_PROJECT_PI4/poses/ronaldinho/553.jpg
# D:\FINAL_PROJECT_PI4/poses/ronaldinho/554.jpg
# D:\FINAL_PROJECT_PI4/poses/ronaldinho/555.jpg
# D:\FINAL_PROJECT_PI4/poses/ronaldinho/556.jpg
# D:\FINAL_PROJECT_PI4/poses/ronaldinho/557.jpg
# D:\FINAL_PROJECT_PI4/poses/ronaldinho/558.jpg
# D:\FINAL_PROJECT_PI4/poses/ronaldinho/559.jpg
# D:\FINAL_PROJECT_PI4/poses/ronaldinho/560.jpg
# D:\FINAL_PROJECT_PI4/poses/ronaldinho/561.jpg
# D:\FINAL_PROJECT_PI4/poses/ronaldinho/562.jpg
# D:\FINAL_PROJECT_PI4/poses/ronaldinho/563.jpg
# D:\FINAL_PROJECT_PI4/poses/ronaldinho/564.jpg
# D:\FINAL_PROJECT_PI4/poses/ronaldinho/565.jpg
# D:\FINAL_PROJECT_PI4/poses/ronaldinho/566.jpg
# D:\FINAL_PROJECT_PI4/poses/ronaldinho/567.jpg
# D:\FINAL_PROJECT_PI4/poses/ronaldinho/568.jpg
# D:\FINAL_PROJECT_PI4/poses/ronaldinho/569.jpg
# D:\FINAL_PROJECT_PI4/poses/ronaldinho/570.jpg
# D:\FINAL_PROJECT_PI4/poses/ronaldinho/571.jpg
# D:\FINAL_PROJECT_PI4/poses/ronaldinho/572.jpg
# D:\FINAL_PROJECT_PI4/poses/ronaldinho/573.jpg
# D:\FINAL_PROJECT_PI4/poses/ronaldinho/574.jpg
# D:\FINAL_PROJECT_PI4/poses/ronaldinho/575.jpg
# D:\FINAL_PROJECT_PI4/poses/ronaldinho/576.jpg
# D:\FINAL_PROJECT_PI4/poses/ronaldinho/577.jpg
# D:\FINAL_PROJECT_PI4/poses/ronaldinho/578.jpg
# D:\FINAL_PROJECT_PI4/poses/ronaldinho/579.jpg
# D:\FINAL_PROJECT_PI4/poses/ronaldinho/580.jpg
# D:\FINAL_PROJECT_PI4/poses/ronaldinho/581.jpg
# D:\FINAL_PROJECT_PI4/poses/ronaldinho/582.jpg
# D:\FINAL_PROJECT_PI4/poses/ronaldinho/583.jpg
# D:\FINAL_PROJECT_PI4/poses/ronaldinho/584.jpg
# D:\FINAL_PROJECT_PI4/poses/ronaldinho/585.jpg
# D:\FINAL_PROJECT_PI4/poses/ronaldinho/586.jpg
# D:\FINAL_PROJECT_PI4/poses/ronaldinho/587.jpg
# D:\FINAL_PROJECT_PI4/poses/ronaldinho/588.jpg
# D:\FINAL_PROJECT_PI4/poses/ronaldinho/589.jpg
# D:\FINAL_PROJECT_PI4/poses/ronaldinho/590.jpg
# D:\FINAL_PROJECT_PI4/poses/ronaldinho/591.jpg
# D:\FINAL_PROJECT_PI4/poses/ronaldinho/592.jpg
# D:\FINAL_PROJECT_PI4/poses/ronaldinho/593.jpg
# D:\FINAL_PROJECT_PI4/poses/ronaldinho/594.jpg
# D:\FINAL_PROJECT_PI4/poses/ronaldinho/595.jpg
# D:\FINAL_PROJECT_PI4/poses/ronaldinho/596.jpg
# ['597.jpg', '598.jpg', '599.jpg', '600.jpg', '601.jpg', '602.jpg', '603.jpg', '604.jpg', '605.jpg', '606.jpg', '607.jpg', '608.jpg', '609.jpg', '610.jpg', '611.jpg', '612.jpg', '613.jpg', '614.jpg', '615.jpg', '616.jpg', '617.jpg', '618.jpg', '619.jpg', '620.jpg', '621.jpg', '622.jpg', '623.jpg', '624.jpg', '625.jpg', '626.jpg', '627.jpg', '628.jpg', '629.jpg', '630.jpg', '631.jpg', '632.jpg', '633.jpg', '634.jpg', '635.jpg']
# D:\FINAL_PROJECT_PI4/poses/three/597.jpg
# D:\FINAL_PROJECT_PI4/poses/three/598.jpg
# D:\FINAL_PROJECT_PI4/poses/three/599.jpg
# D:\FINAL_PROJECT_PI4/poses/three/600.jpg
# D:\FINAL_PROJECT_PI4/poses/three/601.jpg
# D:\FINAL_PROJECT_PI4/poses/three/602.jpg
# D:\FINAL_PROJECT_PI4/poses/three/603.jpg
# D:\FINAL_PROJECT_PI4/poses/three/604.jpg
# D:\FINAL_PROJECT_PI4/poses/three/605.jpg
# D:\FINAL_PROJECT_PI4/poses/three/606.jpg
# D:\FINAL_PROJECT_PI4/poses/three/607.jpg
# D:\FINAL_PROJECT_PI4/poses/three/608.jpg
# D:\FINAL_PROJECT_PI4/poses/three/609.jpg
# D:\FINAL_PROJECT_PI4/poses/three/610.jpg
# D:\FINAL_PROJECT_PI4/poses/three/611.jpg
# D:\FINAL_PROJECT_PI4/poses/three/612.jpg
# D:\FINAL_PROJECT_PI4/poses/three/613.jpg
# D:\FINAL_PROJECT_PI4/poses/three/614.jpg
# D:\FINAL_PROJECT_PI4/poses/three/615.jpg
# D:\FINAL_PROJECT_PI4/poses/three/616.jpg
# D:\FINAL_PROJECT_PI4/poses/three/617.jpg
# D:\FINAL_PROJECT_PI4/poses/three/618.jpg
# D:\FINAL_PROJECT_PI4/poses/three/619.jpg
# D:\FINAL_PROJECT_PI4/poses/three/620.jpg
# D:\FINAL_PROJECT_PI4/poses/three/621.jpg
# D:\FINAL_PROJECT_PI4/poses/three/622.jpg
# D:\FINAL_PROJECT_PI4/poses/three/623.jpg
# D:\FINAL_PROJECT_PI4/poses/three/624.jpg
# D:\FINAL_PROJECT_PI4/poses/three/625.jpg
# D:\FINAL_PROJECT_PI4/poses/three/626.jpg
# D:\FINAL_PROJECT_PI4/poses/three/627.jpg
# D:\FINAL_PROJECT_PI4/poses/three/628.jpg
# D:\FINAL_PROJECT_PI4/poses/three/629.jpg
# D:\FINAL_PROJECT_PI4/poses/three/630.jpg
# D:\FINAL_PROJECT_PI4/poses/three/631.jpg
# D:\FINAL_PROJECT_PI4/poses/three/632.jpg
# D:\FINAL_PROJECT_PI4/poses/three/633.jpg
# D:\FINAL_PROJECT_PI4/poses/three/634.jpg
# D:\FINAL_PROJECT_PI4/poses/three/635.jpg
# ['636.jpg', '637.jpg', '638.jpg', '639.jpg', '640.jpg', '641.jpg', '642.jpg', '643.jpg', '644.jpg', '645.jpg', '646.jpg', '647.jpg', '648.jpg', '649.jpg', '650.jpg', '651.jpg', '652.jpg', '653.jpg', '654.jpg', '655.jpg', '656.jpg', '657.jpg', '658.jpg', '659.jpg', '660.jpg', '661.jpg', '662.jpg', '663.jpg', '664.jpg', '665.jpg', '666.jpg', '667.jpg', '668.jpg', '669.jpg', '670.jpg', '671.jpg', '672.jpg', '673.jpg', '674.jpg', '675.jpg', '676.jpg', '677.jpg', '678.jpg', '679.jpg', '680.jpg', '681.jpg', '682.jpg', '683.jpg', '684.jpg', '685.jpg', '686.jpg', '687.jpg', '688.jpg', '689.jpg', '690.jpg', '691.jpg']
# D:\FINAL_PROJECT_PI4/poses/two/636.jpg
# D:\FINAL_PROJECT_PI4/poses/two/637.jpg
# D:\FINAL_PROJECT_PI4/poses/two/638.jpg
# D:\FINAL_PROJECT_PI4/poses/two/639.jpg
# D:\FINAL_PROJECT_PI4/poses/two/640.jpg
# D:\FINAL_PROJECT_PI4/poses/two/641.jpg
# D:\FINAL_PROJECT_PI4/poses/two/642.jpg
# D:\FINAL_PROJECT_PI4/poses/two/643.jpg
# D:\FINAL_PROJECT_PI4/poses/two/644.jpg
# D:\FINAL_PROJECT_PI4/poses/two/645.jpg
# D:\FINAL_PROJECT_PI4/poses/two/646.jpg
# D:\FINAL_PROJECT_PI4/poses/two/647.jpg
# D:\FINAL_PROJECT_PI4/poses/two/648.jpg
# D:\FINAL_PROJECT_PI4/poses/two/649.jpg
# D:\FINAL_PROJECT_PI4/poses/two/650.jpg
# D:\FINAL_PROJECT_PI4/poses/two/651.jpg
# D:\FINAL_PROJECT_PI4/poses/two/652.jpg
# D:\FINAL_PROJECT_PI4/poses/two/653.jpg
# D:\FINAL_PROJECT_PI4/poses/two/654.jpg
# D:\FINAL_PROJECT_PI4/poses/two/655.jpg
# D:\FINAL_PROJECT_PI4/poses/two/656.jpg
# D:\FINAL_PROJECT_PI4/poses/two/657.jpg
# D:\FINAL_PROJECT_PI4/poses/two/658.jpg
# D:\FINAL_PROJECT_PI4/poses/two/659.jpg
# D:\FINAL_PROJECT_PI4/poses/two/660.jpg
# D:\FINAL_PROJECT_PI4/poses/two/661.jpg
# D:\FINAL_PROJECT_PI4/poses/two/662.jpg
# D:\FINAL_PROJECT_PI4/poses/two/663.jpg
# D:\FINAL_PROJECT_PI4/poses/two/664.jpg
# D:\FINAL_PROJECT_PI4/poses/two/665.jpg
# D:\FINAL_PROJECT_PI4/poses/two/666.jpg
# D:\FINAL_PROJECT_PI4/poses/two/667.jpg
# D:\FINAL_PROJECT_PI4/poses/two/668.jpg
# D:\FINAL_PROJECT_PI4/poses/two/669.jpg
# D:\FINAL_PROJECT_PI4/poses/two/670.jpg
# D:\FINAL_PROJECT_PI4/poses/two/671.jpg
# D:\FINAL_PROJECT_PI4/poses/two/672.jpg
# D:\FINAL_PROJECT_PI4/poses/two/673.jpg
# D:\FINAL_PROJECT_PI4/poses/two/674.jpg
# D:\FINAL_PROJECT_PI4/poses/two/675.jpg
# D:\FINAL_PROJECT_PI4/poses/two/676.jpg
# D:\FINAL_PROJECT_PI4/poses/two/677.jpg
# D:\FINAL_PROJECT_PI4/poses/two/678.jpg
# D:\FINAL_PROJECT_PI4/poses/two/679.jpg
# D:\FINAL_PROJECT_PI4/poses/two/680.jpg
# D:\FINAL_PROJECT_PI4/poses/two/681.jpg
# D:\FINAL_PROJECT_PI4/poses/two/682.jpg
# D:\FINAL_PROJECT_PI4/poses/two/683.jpg
# D:\FINAL_PROJECT_PI4/poses/two/684.jpg
# D:\FINAL_PROJECT_PI4/poses/two/685.jpg
# D:\FINAL_PROJECT_PI4/poses/two/686.jpg
# D:\FINAL_PROJECT_PI4/poses/two/687.jpg
# D:\FINAL_PROJECT_PI4/poses/two/688.jpg
# D:\FINAL_PROJECT_PI4/poses/two/689.jpg
# D:\FINAL_PROJECT_PI4/poses/two/690.jpg
# D:\FINAL_PROJECT_PI4/poses/two/691.jpg
# 0 processed files
# (0, 1002)
# Empty DataFrame
# Columns: [pose, camera_angle, f1, f2, f3, f4, f5, f6, f7, f8, f9, f10, f11, f12, f13, f14, f15, f16, f17, f18, f19, f20, f21, f22, f23, f24, f25, f26, f27, f28, f29, f30, f31, f32, f33, f34, f35, f36, f37, f38, f39, f40, f41, f42, f43, f44, f45, f46, f47, f48, f49, f50, f51, f52, f53, f54, f55, f56, f57, f58, f59, f60, f61, f62, f63, f64, f65, f66, f67, f68, f69, f70, f71, f72, f73, f74, f75, f76, f77, f78, f79, f80, f81, f82, f83, f84, f85, f86, f87, f88, f89, f90, f91, f92, f93, f94, f95, f96, f97, f98, ...]
# Index: []
#
# [0 rows x 1002 columns]

# %%
# Getting tendon activations : 
# Train the RRM using the screenshots csv and
# load the real_hands csv into the Ridge Regression Model

def read_raw_data():
    data = pd.read_csv('data/hand_data3_separated.csv',  index_col=False)

    # remove punctuation
    data['desc_list'] = data.description.apply(lambda x: [i for i in re.sub(r'[^\w\s]','',str(x)).lower().split()])
    data['desc_str'] = data.desc_list.apply(lambda x: ' '.join(x))

    #add one-hot encoding
    camera_data = pd.get_dummies(data.camera_angle)
    data = pd.concat([data, camera_data], axis=1)
    cols = data.columns.tolist()
    cols = cols[:8] + cols[-4:] + cols[8:-4]
    data = data[cols]
    
    #get words and vocabs
    words = [y for x in data.desc_list for y in x]
    vocab = list(set(words))
    print('number of unique words in our data:', len(vocab), '\nnumber of word tokens in our data: ', len(words))
    
    return data, words, vocab

def read_in_data():
    train_data = pd.read_pickle("data/train_data3_separated.pkl")
    test_data = pd.read_pickle("data/test_data3_separated.pkl")
    return train_data, test_data

def stack_training_data(mydata):
    s = mydata.apply(lambda x: pd.Series(x['desc_list']),axis=1).stack().reset_index(level=1, drop=True)
    s.name = 'word'
    mydata = mydata.join(s)
    return mydata

def remove_unwated_words(mydata, vocab, words):
    wanted_words = list(set(words))
    unwanted_words = {'hand', 'and', 'the', 'a', 'with', 'is', 'are', 'to', 'of', 'finger', 'fingers', 'thumb'}
    unwanted_tags = {}
    for curr_word in vocab:
        if curr_word in unwanted_words:
            wanted_words.remove(curr_word)
    mydata = mydata.loc[mydata['word'].isin(wanted_words)]
    return mydata

_, words, vocab = read_raw_data()
train_data, test_data = read_in_data()
train_data[:10]

data, words, vocab = read_raw_data()

data.columns[:15]

START_COL = 'T1' 
END_COL = 'T5'
V_START_COL = 'f1'
V_END_COL = 'f1000'

y = train_data.ix[:,START_COL:END_COL].as_matrix()
X = train_data.ix[:,V_START_COL:V_END_COL].as_matrix()
y_test = test_data.ix[:,START_COL:END_COL].as_matrix()
X_test = test_data.ix[:,V_START_COL:V_END_COL].as_matrix()
y_all = data.ix[:,START_COL:END_COL].as_matrix()
X_all = data.ix[:,V_START_COL:V_END_COL].as_matrix()

print("train", X.shape, y.shape)
print("test", X_test.shape, y_test.shape)
print("all", X_all.shape, y_all.shape)


model = Ridge(alpha=0.001, copy_X=True, fit_intercept=True, max_iter=None, normalize=True, 
              random_state=False, solver='auto', tol=0.01)
model.fit(X, y)

# %%
# Getting tendons for real hands
data = pd.read_csv('data/real-hands.csv',  index_col=False)


X_rh = data.ix[:,V_START_COL:V_END_COL].as_matrix()

# Getting the poses to add them in the csv
poses_list = data.ix[:,'pose']
poses_row = np.asarray([poses_list])
poses = poses_row.transpose()

# Getting the tendon values using the model from Boise
y_predicted_rh = model.predict(X_rh)
print("Predicted tendons") 
print(np.around(y_predicted_rh, decimals=1))

# Can be uncommented to check for dimensions in case
# they do not seem to match

print(X_rh.shape)
print(type(X_rh))
print(y_predicted_rh.shape)
print(type(y_predicted_rh))
print(poses.shape)
print(type(poses))

# Adding the camera angle
#camera_angle = np.asarray([["straight_on"] * X_rh.shape[0]]).transpose()
#partial_result = np.concatenate((poses, camera_angle), axis = 1)

# Adding poses to the tendon values
partial_result = np.concatenate((poses, y_predicted_rh), axis = 1)

# Adding the result to the features
final2 = np.concatenate((partial_result, X_rh), axis = 1)

# Creating the feature list to add as header
feature_list = []
for i in range(1, 1001):
        feature_list.append("f" + str(i))

tendon_list = ["pose", "T1", "T2", "T3", "T4", "T5"]

# Adding the feature list to the other headers 
tendon_list.extend(feature_list)

# Saving the results in a csv
df = pd.DataFrame(final2)
print(tendon_list)
print(df)
df.columns = tendon_list

df.to_csv("data/real-hands-with-tendons.csv")

# %%
# Using a CNN in order to verify if integrating tendon activation
# improves gesture recognition. We used tf.

# File to pass our CSV through another NN
path_csv = "data/real-hands-with-tendons.csv"
seed = 42
np.random.seed(seed)

# load dataset from csv
dataset = np.loadtxt(path_csv, delimiter=',', skiprows=1)

# split into input and output variables
X = dataset[:,2:]
Y = dataset[:,1:2]

print(X.shape)
print(Y.shape)
print(X, Y)

# split the data into training (67%) and testing (33%)
(X_train, X_test, Y_train, Y_test) = train_test_split(X, Y, test_size=0.33, random_state=seed)

print(X_train.shape)
print(Y_train.shape)

print(X_test.shape)
print(Y_test.shape)

# create the model
model = Sequential()
model.add(Dense(100, input_dim=1005, init='uniform', activation='relu'))
model.add(Dense(50, init='uniform', activation='relu'))
model.add(Dense(1, init='uniform', activation='relu'))

# compile the model
history = model.compile(loss=losses.mean_squared_error, optimizer='adam', metrics=['accuracy'])

# fit the model
model.fit(X_train, Y_train, validation_data=(X_test, Y_test), nb_epoch=30, batch_size=15)

# evaluate the model
scores = model.evaluate(X_test, Y_test)
print("Accuracy: %.2f%%" %(scores[1]*100))
